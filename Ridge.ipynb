# %%
# import necessary lib
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib 
matplotlib.rcParams["figure.figsize"] = (20,10)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## import data into DataFrame

# %%
df1 = pd.read_csv("WA_housing_for_predicting_cleaned.csv")
df1.head()
# Out:
#    Unnamed: 0                 date      price  bedrooms  bathrooms  \
# 0           0  2014-05-02 00:00:00   313000.0       3.0       1.50
# 1           1  2014-05-02 00:00:00  2384000.0       5.0       2.50
# 2           2  2014-05-02 00:00:00   342000.0       3.0       2.00
# 3           3  2014-05-02 00:00:00   420000.0       3.0       2.25
# 4           4  2014-05-02 00:00:00   550000.0       4.0       2.50
#
#    sqft_living  sqft_lot  floors  condition  sqft_above  sqft_basement  \
# 0         1340      7912     1.5          3        1340              0
# 1         3650      9050     2.0          5        3370            280
# 2         1930     11947     1.0          4        1930              0
# 3         2000      8030     1.0          4        1000           1000
# 4         1940     10500     1.0          4        1140            800
#
#    yr_built  yr_renovated                    street       city  statezip  \
# ...

# %%
df1.shape
# Out:
# (4546, 20)

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'street', 'city', 'statezip', 'state',
#        'zip', 'year_sold', 'age_of_house'],
#       dtype='object')

# %%
df2 = df1.drop(columns=['Unnamed: 0'])

# %%
df2.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     1.5          3        1340              0      1955          2005
# 1     2.0          5        3370            280      1921             0
# 2     1.0          4        1930              0      1966             0
# 3     1.0          4        1000           1000      1963             0
# 4     1.0          4        1140            800      1976          1992
#
# ...

# %%
len(df2)
# Out:
# 4546

# %% [markdown]
# ## Create new DataFrame with necessary columns (features) to create our model

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X_city_encoder = LabelEncoder()

# %%
X_city_encoder.fit(df2["city"])
# Out:
# LabelEncoder()

# %%
X_city_encoder = X_city_encoder.transform(df2["city"])

# %%
X_city_encoder
# Out:
# array([36, 35, 18, ..., 32, 35,  9])

# %%
len(X_city_encoder)
# Out:
# 4546

# %%
df2.insert(6, "city_encoder", X_city_encoder, True)

# %%
df2
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4541  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4542  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4543  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4544  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4545  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  city_encoder  floors  condition  sqft_above  sqft_basement  \
# ...

# %%
df3= df2[["bedrooms","bathrooms","sqft_living","condition","age_of_house"]]

# %%
df3.head()
# Out:
#    bedrooms  bathrooms  sqft_living  condition  age_of_house
# 0       3.0       1.50         1340          3            66
# 1       5.0       2.50         3650          5           100
# 2       3.0       2.00         1930          4            55
# 3       3.0       2.25         2000          4            58
# 4       4.0       2.50         1940          4            45

# %%
len(df3)
# Out:
# 4546

# %%
rating = []
for row in df3['condition']:
        if row == 1 :    rating.append('worst')
        elif row == 2:   rating.append('bad')
        elif row == 3:  rating.append('normal')
        elif row == 4:  rating.append('good')
        else:           rating.append('excellent')

# %%
rating
# Out:
# ['normal',
#  'excellent',
#  'good',
#  'good',
#  'good',
#  'normal',
#  'normal',
#  'normal',
#  'good',
#  'normal',
#  'normal',
#  'excellent',
#  'normal',
#  'good',
#  'normal',
#  'good',
#  'good',
#  'normal',
#  'normal',
#  'normal',
#  'excellent',
#  'good',
#  'normal',
#  'normal',
#  'normal',
#  'good',
#  'good',
#  'excellent',
#  'normal',
#  'good',
#  'good',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'good',
#  'good',
#  'excellent',
#  'good',
#  'good',
#  'good',
#  'good',
#  'normal',
#  'bad',
#  'normal',
#  'good',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'good',
#  'normal',
#  'normal',
#  'good',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'good',
#  'good',
#  'normal',
#  'excellent',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'normal',
#  'good',
#  'normal',
#  'good',
# ...

# %%
df3['house_condition'] = rating
df3.head()
# Out:
#    bedrooms  bathrooms  sqft_living  condition  age_of_house house_condition
# 0       3.0       1.50         1340          3            66          normal
# 1       5.0       2.50         3650          5           100       excellent
# 2       3.0       2.00         1930          4            55            good
# 3       3.0       2.25         2000          4            58            good
# 4       4.0       2.50         1940          4            45            good

# %%
df3 = pd.get_dummies(df3)
df3.head()
# Out:
#    bedrooms  bathrooms  sqft_living  condition  age_of_house  \
# 0       3.0       1.50         1340          3            66
# 1       5.0       2.50         3650          5           100
# 2       3.0       2.00         1930          4            55
# 3       3.0       2.25         2000          4            58
# 4       4.0       2.50         1940          4            45
#
#    house_condition_bad  house_condition_excellent  house_condition_good  \
# 0                    0                          0                     0
# 1                    0                          1                     0
# 2                    0                          0                     1
# 3                    0                          0                     1
# 4                    0                          0                     1
#
#    house_condition_normal  house_condition_worst
# 0                       1                      0
# 1                       0                      0
# ...

# %%
df3.drop(['house_condition_worst'], axis=1)
# Out:
#       bedrooms  bathrooms  sqft_living  condition  age_of_house  \
# 0          3.0       1.50         1340          3            66
# 1          5.0       2.50         3650          5           100
# 2          3.0       2.00         1930          4            55
# 3          3.0       2.25         2000          4            58
# 4          4.0       2.50         1940          4            45
# ...        ...        ...          ...        ...           ...
# 4541       3.0       1.75         1510          4            67
# 4542       3.0       2.50         1460          3            38
# 4543       3.0       2.50         3010          3            12
# 4544       4.0       2.00         2090          3            47
# 4545       3.0       2.50         1490          4            31
#
#       house_condition_bad  house_condition_excellent  house_condition_good  \
# 0                       0                          0                     0
# ...

# %%
y =df2["price"].values.reshape(-1, 1)

# %%
len(y)
# Out:
# 4546

# %%
X  =df3[["bedrooms","bathrooms","sqft_living","house_condition_bad","house_condition_normal","house_condition_good","house_condition_excellent","age_of_house"]]

# %%
X
# Out:
#       bedrooms  bathrooms  sqft_living  house_condition_bad  \
# 0          3.0       1.50         1340                    0
# 1          5.0       2.50         3650                    0
# 2          3.0       2.00         1930                    0
# 3          3.0       2.25         2000                    0
# 4          4.0       2.50         1940                    0
# ...        ...        ...          ...                  ...
# 4541       3.0       1.75         1510                    0
# 4542       3.0       2.50         1460                    0
# 4543       3.0       2.50         3010                    0
# 4544       4.0       2.00         2090                    0
# 4545       3.0       2.50         1490                    0
#
#       house_condition_normal  house_condition_good  house_condition_excellent  \
# 0                          1                     0                          0
# 1                          0                     0                          1
# ...

# %%
len(X)
# Out:
# 4546

# %%
# Split our data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
#joblib.save(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-d37df53b41b1> in <module>
# ----> 1 joblib.save(y)
#
# NameError: name 'joblib' is not defined

# %%
from sklearn.linear_model import Ridge
linear_ridge_model= Ridge()
linear_ridge_model.fit(X_train_scaled, y_train_scaled)
# Out:
# Ridge()

# %%
plt.scatter(linear_ridge_model.predict(X_train_scaled), linear_ridge_model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(linear_ridge_model.predict(X_test_scaled), linear_ridge_model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

predictions = linear_ridge_model.predict(X_test_scaled)

# %%
MSE = mean_squared_error(y_test_scaled, predictions)
r2 = linear_ridge_model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.4635472257888352, R2: 0.5140160892157459

# %%
predictions = linear_ridge_model.predict(X_train_scaled)
MSE = mean_squared_error(y_train_scaled, predictions)
r2 = linear_ridge_model.score(X_train_scaled, y_train_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.4568987000530266, R2: 0.5431012999469734

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(Ridge(), X_test_scaled, y_test_scaled, cv=cv)
# Out:
# array([0.51854516, 0.53076087, 0.57257201, 0.49382755, 0.49811385])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression

def find_best_model_using_gridsearchcv(X_test_scaled,y_test_scaled):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'normalize': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(X,y)
# Out:
#                model  best_score                               best_params
# 0  linear_regression    0.566633                       {'normalize': True}
# 1              lasso    0.566661       {'alpha': 2, 'selection': 'random'}
# 2      decision_tree    0.126072  {'criterion': 'mse', 'splitter': 'best'}

# %%
linear_ridge_model.coef_
# Out:
# array([[-0.16507528,  0.1723836 ,  0.73316385, -0.00456087,  0.07808104,
#          0.08049596,  0.09598541,  0.22650097]])

# %%
linear_ridge_model.intercept_
# Out:
# array([1.71593191e-16])

# %%
X_city_encoder
# Out:
# array([36, 35, 18, ..., 32, 35,  9])

# %%
#predictions = linear_ridge_model.predict(X_test_scaled)
#pd.DataFrame({"Prediction": predictions, "Actual": y_test_scaled})

# %%
import joblib
filename = 'ridge_model.sav'
joblib.dump(linear_ridge_model, filename)
# Out:
# ['ridge_model.sav']

# %%
joblib.dump(y_scaler,"y_scaler.sav")
joblib.dump(X_scaler,"X_scaler.sav")
# Out:
# ['X_scaler.sav']

# %%
loaded_y_scaler = joblib.load("y_scaler.sav")
loaded_X_scaler = joblib.load("X_scaler.sav")

# %%
house_data_scaled = loaded_X_scaler.transform([[3,3,1200,0,0,1,0,25]])

# %%
loaded_y_scaler.inverse_transform(linear_ridge_model.predict(house_data_scaled))
# Out:
# array([[312621.25059229]])

# %%
condition_array = [0,0,0,0]
condition_array[condition]=1

# %%
predicted_price = loaded_y_scaler.inverse_transform(linear_ridge_model.predict(house_data_scaled))
predicted_price
# Out:
# array([[312621.25059229]])

# %%
predicted_price_rounded = "${:,.2f}".format(round(predicted_price[0][0]))
print(predicted_price_rounded)
# Out:
# $312,621.00

# %%
numBedRooms = input("enter bedrooms: ")
numBathRooms = input("enter bathrooms: ")
houseSq = input("enter sqft_living: ")
condition = input("enter condition (1=worst, 2=bad, 3=normal,4=good,5=excellent): ")
houseAge = input("enter Age of house: ")
# Out:
# enter bedrooms: 5
# enter bathrooms: 4
# enter sqft_living: 2400
# enter condition (1=worst, 2=bad, 3=normal,4=good,5=excellent): 5
# enter Age of house: 10

# %%
condition_array=[]
condition_array = [0,0,0,0] 
if int(condition) != 0 :
        condition_array[(int(condition)-2)] = 1
condition_array
# Out:
# [0, 0, 0, 1]

# %%
house_data_scaled =loaded_X_scaler.transform([[numBedRooms,numBathRooms,houseSq,condition_array[0],condition_array[1],condition_array[2],condition_array[3],houseAge]])
predicted_price = loaded_y_scaler.inverse_transform(linear_ridge_model.predict(house_data_scaled))
currency_string = "${:,.2f}".format(round(predicted_price[0][0]))
print(currency_string)
#predicted_price_rounded =
# Out:
# $609,674.00
